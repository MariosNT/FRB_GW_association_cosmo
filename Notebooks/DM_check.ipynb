# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import astropy.units as u
from astropy.cosmology import FlatLambdaCDM
import astropy.constants as const
from astropy.cosmology import Planck18

# %%
cosmo=FlatLambdaCDM(H0=Planck18.H0,Om0=Planck18.Om0,Tcmb0=Planck18.Tcmb0)
dL=cosmo.luminosity_distance(
    z=0.011
    )
print(dL.to(u.kpc))
# Out:
# 49149.46153934325 kpc

# %%
from astropy.coordinates import SkyCoord
RA='02d08m42.70s'
DEC='+71d02m06.94s'

c_icrs = SkyCoord(ra=RA, dec=DEC, frame='icrs')
c_icrs.galactic
# Out:
# <SkyCoord (Galactic): (l, b) in deg
#     (119.42996792, 8.45548517)>

# %%
from mwprop.ne2001p import *
from mwprop.ne2001p.NE2001 import ne2001

Dk,Dv,Du,Dd = ne2001(ldeg=119.42996792,bdeg=8.45548517,dmd=49149.46,ndir=0,classic=False)
